# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("/home/cygnus/fujimoto/Cygnus-X_Molecular_Cloud_Analysis/Binary_classification/data/FUGIN/processed_data/FGN_01100+0000/thresh_up_low/lower-1.66_data_size128.npy")

# %%
data_num = 20
print(data[data_num].shape)
plt.imshow(np.sum(data[data_num], axis=0), vmin=0, vmax=4)
plt.show()
# Out:
# (32, 128, 128)
